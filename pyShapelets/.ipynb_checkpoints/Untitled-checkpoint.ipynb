# %%
import pandas as pd
import numpy as np
from pyshapelets.shapelet_extraction.extract_shapelets import fit, extract_shapelet

# def adjustProbabilities(probs):
#     for i in range(len(probs)):
#         j = np.random.choice(len(probs), size=1)[0]
#         p, p2 = probs[i], probs[j]
#         mut = np.random.uniform(-min(p, p2), min(p, p2), size=1)[0]
#         probs[i] += mut
#         probs[j] -= mut
#     return probs
#
# print(adjustProbabilities([0.1,0.1,0.1,0.5,0.1,0.1]))

# # Read in the coffee dataset
from pyshapelets.util.util import calculate_stats, subsequence_dist, subsequence_dist_z_space, sdist_new
from pyshapelets.util.util import calculate_stats_old
from pyshapelets.visualization.visualization import run

# data = pd.read_csv('data/Coffee.csv', header=None)
# # data = data.sample(20)
#
# # Set the column names
# feature_cols = []
# for i in range(286): feature_cols.append('x_'+str(i))
# data.columns = feature_cols + ['label']
# print(len(data))

# pre-pruning:

# no pre-pruning:
# Brute force algorithm took 114.40455603599548
# 0.12408303257700161 per iteration

data = pd.read_csv('data/Beef.csv', header=None)
data = data.sample(25 , random_state=1337)

# Set the column names
feature_cols = []
for i in range(470): feature_cols.append('x_'+str(i))
data.columns = feature_cols + ['label']

# data = data[data['label'] > 0]

# data = pd.read_csv('data/Wine.csv', header=None)
# # data = data.sample(20)
#
# # Set the column names
# feature_cols = []
# for i in range(234): feature_cols.append('x_'+str(i))
# data.columns = feature_cols + ['label']
# from collections import Counter
# print(Counter(data['label']))

# data = pd.read_csv('data/ArrowHead.csv', header=None)
# feature_cols = []
# for i in range(251): feature_cols.append('x_'+str(i))
# data.columns = feature_cols + ['label']
# print(len(data))

# Split in timeseries and labels
labels = data['label'].values
timeseries = data.drop('label', axis=1).values

# m_uv = np.around(calculate_stats(timeseries[0], timeseries[1])[4], 7)
# m_uv_old = np.around(calculate_stats_old(timeseries[0], timeseries[1])[4], 7)
#
# print(m_uv.shape)
# print(m_uv_old.shape)
#
# for i in range(m_uv.shape[0]):
#     for j in range(m_uv.shape[1]):
#         if float(m_uv[i, j]) != float(m_uv_old[i, j]):
#             print(i, j, m_uv[i,j], m_uv_old[i,j])
#
# assert np.array_equal(m_uv, m_uv_old)

print(labels)
print(timeseries)

if __name__ == "__main__":
    print('Fitting tree')
    tree = fit(timeseries, labels)
    
    print('Shapelet')
    print(tree.shapelet)
    print('Distance')
    print(tree.distance)

    distances = []

    for ts, label in zip(timeseries, labels):
        d, idx = subsequence_dist(ts, tree.shapelet)
        distances.append((d, label))

    #print([x for x in sorted(distances, key=lambda x: x[0])])

    distances = []

    for ts, label in zip(timeseries, labels):
        stats = calculate_stats(tree.shapelet, ts)
        d = sdist_new(tree.shapelet, ts, 0, stats)
        distances.append((d, label))

    #print([x for x in sorted(distances, key=lambda x: x[0])])

    distances = []

    for ts, label in zip(timeseries, labels):
        stats = calculate_stats(tree.right.shapelet, ts)
        d = sdist_new(tree.right.shapelet, ts, 0, stats)
        distances.append((d, label))

    #print([x for x in sorted(distances, key=lambda x: x[0])])


    # tree.populate_class_probs(timeseries[:-1], labels[:-1])
    # tree.recalculate_distances(timeseries[:-1], labels[:-1])

    for ts, label in zip(timeseries, labels):
        print(label)
        print(tree.predict([ts], z_norm=True))
        print('-'*100)

    # tree = fit(timeseries, labels, max_len=50, min_len=50)
    # print('Creating visualization')
    # run(tree)
# Out:
# [3 5 4 5 5 3 1 2 2 5 5 2 1 5 1 3 4 1 4 3 1 4 5 1 4]
# [[-0.1939   -0.20332  -0.20712  ..., -1.5928   -1.5915   -1.5934  ]
#  [-0.1775   -0.17332  -0.15675  ..., -2.0179   -2.0059   -2.0054  ]
#  [-0.067976 -0.053382 -0.04366  ..., -1.9506   -1.9523   -1.949   ]
#  ...,
#  [-0.17582  -0.18426  -0.18529  ..., -1.9901   -1.9863   -1.9987  ]
#  [-0.2081   -0.19697  -0.17793  ..., -0.97961  -0.96814  -0.98033 ]
#  [-0.061762 -0.066382 -0.077454 ..., -1.942    -1.9353   -1.9232  ]]
# Fitting tree
# 0 / 25
# [(0.0, 3), (4.0000000000012248e-05, 5), (6.0000000000004494e-05, 5), (7.0000000000014495e-05, 5), (9.0000000000006741e-05, 3), (0.00013000000000001899, 4), (0.00026000000000001022, 3), (0.00068999999999999617, 1), (0.00093000000000001415, 4), (0.00095999999999998864, 5), (0.00095999999999998864, 3), (0.0014300000000000146, 4), (0.0023099999999999787, 2), (0.002720000000000028, 1), (0.0028299999999999714, 2), (0.0029000000000000137, 5), (0.0030700000000000172, 1), (0.0031799999999999884, 4), (0.0037200000000000011, 5), (0.004290000000000016, 1), (0.0049400000000000277, 1), (0.0051500000000000157, 5), (0.0052800000000000069, 2), (0.029170000000000001, 1), (0.03347, 4)]
# [(0.0, 3), (0.00016000000000002124, 5), (0.00029999999999999472, 3), (0.00041000000000002146, 4), (0.0004699999999999982, 5), (0.00051999999999999269, 1), (0.00060999999999999943, 5), (0.00070999999999998842, 5), (0.00071000000000001617, 5), (0.00078000000000000291, 3), (0.0010700000000000154, 3), (0.0017800000000000038, 4), (0.002030000000000004, 1), (0.0022199999999999998, 4), (0.0023200000000000165, 4), (0.0023400000000000087, 1), (0.0030000000000000027, 5), (0.0037299999999999833, 2), (0.0041400000000000048, 2), (0.004269999999999996, 5), (0.0046299999999999952, 2), (0.0047800000000000065, 1), (0.0066999999999999837, 1), (0.021669999999999995, 1), (0.031379999999999991, 4)]
# [(0.0, 3), (0.00028999999999995696, 5), (0.00029000000000001247, 5), (0.0005200000000000482, 4), (0.00069000000000002393, 5), (0.00075000000000000067, 1), (0.00083000000000002516, 2), (0.0009800000000000364, 1), (0.0012599999999999834, 3), (0.0012999999999999956, 3), (0.0014799999999999536, 4), (0.0015799999999999703, 4), (0.0020199999999999663, 4), (0.0022900000000000142, 5), (0.0032500000000000029, 3), (0.0033200000000000451, 5), (0.0040000000000000036, 2), (0.0042699999999999683, 5), (0.0043199999999999628, 1), (0.0057100000000000484, 1), (0.0067300000000000415, 1), (0.0075299999999999534, 2), (0.0080699999999999661, 5), (0.017870000000000025, 1), (0.027580000000000021, 4)]
]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-8ae344f44dcf> in <module>()
#      82 if __name__ == "__main__":
#      83     print('Fitting tree')
# ---> 84     tree = fit(timeseries, labels)
#      85
#      86     print('Shapelet')
#
# /home/guillaume/Documents/EDF/pyShapelets/pyshapelets/shapelet_extraction/extract_shapelets.py in fit(X, y, max_depth, min_samples_split, min_len, max_len)
#      30     if (max_depth is None or max_depth > 0) and len(X) > min_samples_split and len(np.unique(y)) > 1:
#      31         # TODO: pass the distance along with this shapelet so we don't need to recalculate this!
# ---> 32         shapelet = fast_shapelet_discovery(X, y)
#      33         distance = check_candidate(X, y, shapelet)[1]
#      34         node = ShapeletTree(right=None, left=None, shapelet=shapelet, distance=distance,
#
# /home/guillaume/Documents/EDF/pyShapelets/pyshapelets/shapelet_extraction/fast_shapelets.py in fast_shapelet_discovery(timeseries, labels, m)
#     140                 for (L, S) in H:
#     141                     R = util.sdist(ts[i:i+l], S)
# --> 142                     if util.upperIG(L, R, timeseries, labels) < max_gain:
#     143                         broken = True
#     144                         break # Continue with next i
#
# /home/guillaume/Documents/EDF/pyShapelets/pyshapelets/util/util.py in upperIG(L, R, timeseries, labels)
#     259
#     260             ig = information_gain(left_partition + temp_left_partition, right_partition + temp_right_partition,
# --> 261                                   prior_entropy)
#     262             max_ig = max(ig, max_ig)
#     263
#
# /home/guillaume/Documents/EDF/pyShapelets/pyshapelets/util/util.py in information_gain(labels_left, labels_right, prior_entropy)
#     129     if total_length == 0:
#     130         print('break')
# --> 131     ig_left = float(len(labels_left)) / total_length * calculate_dict_entropy(labels_left)
#     132     ig_right = float(len(labels_right)) / total_length * calculate_dict_entropy(labels_right)
#     133     return prior_entropy - (ig_left + ig_right)
#
# /home/guillaume/Documents/EDF/pyShapelets/pyshapelets/util/util.py in calculate_dict_entropy(data)
#     122     for key in cntr:
#     123         cntr[key] /= total
# --> 124     return calculate_entropy(list(cntr.values()))
#     125
#     126
#
# /home/guillaume/Documents/EDF/pyShapelets/pyshapelets/util/util.py in calculate_entropy(probabilities)
#     113 def calculate_entropy(probabilities):
#     114     # This takes logarithm with base 10 instead of 2 (should not be a problem)
# --> 115     return entropy(probabilities)
#     116     #return sum([-prob * np.log(prob)/np.log(2) if prob != 0 else 0 for prob in probabilities])
#     117
#
# /home/guillaume/anaconda3/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py in entropy(pk, qk, base)
#    2489     """
#    2490     pk = asarray(pk)
# -> 2491     pk = 1.0*pk / np.sum(pk, axis=0)
#    2492     if qk is None:
#    2493         vec = entr(pk)
#
# /home/guillaume/anaconda3/lib/python3.5/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims)
#    1846     else:
#    1847         return _methods._sum(a, axis=axis, dtype=dtype,
# -> 1848                             out=out, **kwargs)
#    1849
#    1850
#
# /home/guillaume/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:
